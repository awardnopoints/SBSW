# %%
def call_weather_api(url):
    """Calls weather API and returns info"""

    req = requests.get(url)
    return req

def write_weather (weatherData):
    """Retrieves weather information from openweathermap and stores as JSON"""

    req_weather = weatherData.text
    json_weather = json.loads(req_weather)
    return json_weather

# %%
url = "http://api.openweathermap.org/data/2.5/forecast?id=2964574&units=metric&APPID=bb260f441e7da59a28734895b6574b4d"
#url = "http://api.apixu.com/v1/forecast.json?key=21796649376d437983593814182806&q=Dublin"

# %%
weatherData = call_weather_api(url)
json_weather = write_weather(weatherData)

# %%
json_weather
# Out:
# {'city': {'coord': {'lat': 53.344, 'lon': -6.2672},
#   'country': 'IE',
#   'id': 2964574,
#   'name': 'Dublin'},
#  'cnt': 40,
#  'cod': '200',
#  'list': [{'clouds': {'all': 0},
#    'dt': 1530187200,
#    'dt_txt': '2018-06-28 12:00:00',
#    'main': {'grnd_level': 1036.38,
#     'humidity': 82,
#     'pressure': 1036.38,
#     'sea_level': 1040.86,
#     'temp': 22.64,
#     'temp_kf': 4.46,
#     'temp_max': 22.64,
#     'temp_min': 18.18},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'clear sky',
#      'icon': '01d',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 51.0004, 'speed': 3.36}},
#   {'clouds': {'all': 0},
#    'dt': 1530198000,
#    'dt_txt': '2018-06-28 15:00:00',
#    'main': {'grnd_level': 1035.7,
#     'humidity': 82,
#     'pressure': 1035.7,
#     'sea_level': 1040.21,
#     'temp': 21.66,
#     'temp_kf': 3.34,
#     'temp_max': 21.66,
#     'temp_min': 18.31},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'clear sky',
#      'icon': '01d',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 55.5059, 'speed': 3.48}},
#   {'clouds': {'all': 12},
#    'dt': 1530208800,
#    'dt_txt': '2018-06-28 18:00:00',
#    'main': {'grnd_level': 1034.73,
#     'humidity': 81,
#     'pressure': 1034.73,
#     'sea_level': 1039.36,
#     'temp': 20.64,
#     'temp_kf': 2.23,
#     'temp_max': 20.64,
#     'temp_min': 18.42},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'few clouds',
#      'icon': '02d',
#      'id': 801,
#      'main': 'Clouds'}],
#    'wind': {'deg': 19.0049, 'speed': 2.11}},
#   {'clouds': {'all': 0},
#    'dt': 1530219600,
#    'dt_txt': '2018-06-28 21:00:00',
#    'main': {'grnd_level': 1034.85,
#     'humidity': 83,
#     'pressure': 1034.85,
#     'sea_level': 1039.53,
#     'temp': 19.05,
#     'temp_kf': 1.11,
#     'temp_max': 19.05,
#     'temp_min': 17.93},
#    'sys': {'pod': 'n'},
#    'weather': [{'description': 'clear sky',
#      'icon': '01n',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 6.00061, 'speed': 3.19}},
#   {'clouds': {'all': 0},
#    'dt': 1530230400,
#    'dt_txt': '2018-06-29 00:00:00',
#    'main': {'grnd_level': 1034.86,
#     'humidity': 88,
#     'pressure': 1034.86,
#     'sea_level': 1039.7,
#     'temp': 17.03,
#     'temp_kf': 0,
#     'temp_max': 17.03,
#     'temp_min': 17.03},
#    'sys': {'pod': 'n'},
#    'weather': [{'description': 'clear sky',
#      'icon': '01n',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 26.0042, 'speed': 3.96}},
#   {'clouds': {'all': 0},
#    'dt': 1530241200,
#    'dt_txt': '2018-06-29 03:00:00',
#    'main': {'grnd_level': 1034.33,
#     'humidity': 94,
#     'pressure': 1034.33,
#     'sea_level': 1039.02,
#     'temp': 15.78,
#     'temp_kf': 0,
#     'temp_max': 15.78,
#     'temp_min': 15.78},
#    'sys': {'pod': 'n'},
#    'weather': [{'description': 'clear sky',
#      'icon': '01n',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 34.501, 'speed': 2.47}},
#   {'clouds': {'all': 0},
#    'dt': 1530252000,
#    'dt_txt': '2018-06-29 06:00:00',
#    'main': {'grnd_level': 1033.8,
#     'humidity': 94,
#     'pressure': 1033.8,
#     'sea_level': 1038.48,
#     'temp': 15.7,
#     'temp_kf': 0,
#     'temp_max': 15.7,
#     'temp_min': 15.7},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'clear sky',
#      'icon': '01d',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 36.0038, 'speed': 2.21}},
#   {'clouds': {'all': 0},
#    'dt': 1530262800,
#    'dt_txt': '2018-06-29 09:00:00',
#    'main': {'grnd_level': 1033.82,
#     'humidity': 88,
#     'pressure': 1033.82,
#     'sea_level': 1038.58,
#     'temp': 17.03,
#     'temp_kf': 0,
#     'temp_max': 17.03,
#     'temp_min': 17.03},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'clear sky',
#      'icon': '01d',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 78.5009, 'speed': 2.87}},
#   {'clouds': {'all': 0},
#    'dt': 1530273600,
#    'dt_txt': '2018-06-29 12:00:00',
#    'main': {'grnd_level': 1033.33,
#     'humidity': 86,
#     'pressure': 1033.33,
#     'sea_level': 1037.92,
#     'temp': 17.53,
#     'temp_kf': 0,
#     'temp_max': 17.53,
#     'temp_min': 17.53},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'clear sky',
#      'icon': '01d',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 82.0031, 'speed': 3.51}},
#   {'clouds': {'all': 0},
#    'dt': 1530284400,
#    'dt_txt': '2018-06-29 15:00:00',
#    'main': {'grnd_level': 1032.22,
#     'humidity': 85,
#     'pressure': 1032.22,
#     'sea_level': 1036.69,
#     'temp': 17.82,
#     'temp_kf': 0,
#     'temp_max': 17.82,
#     'temp_min': 17.82},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'clear sky',
#      'icon': '01d',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 70, 'speed': 3.97}},
#   {'clouds': {'all': 0},
#    'dt': 1530295200,
#    'dt_txt': '2018-06-29 18:00:00',
#    'main': {'grnd_level': 1030.75,
#     'humidity': 85,
#     'pressure': 1030.75,
#     'sea_level': 1035.27,
#     'temp': 17.78,
#     'temp_kf': 0,
#     'temp_max': 17.78,
#     'temp_min': 17.78},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'clear sky',
#      'icon': '01d',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 56.0028, 'speed': 3.57}},
#   {'clouds': {'all': 0},
#    'dt': 1530306000,
#    'dt_txt': '2018-06-29 21:00:00',
#    'main': {'grnd_level': 1030.19,
#     'humidity': 89,
#     'pressure': 1030.19,
#     'sea_level': 1034.73,
#     'temp': 17.08,
#     'temp_kf': 0,
#     'temp_max': 17.08,
#     'temp_min': 17.08},
#    'sys': {'pod': 'n'},
#    'weather': [{'description': 'clear sky',
#      'icon': '01n',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 26.0004, 'speed': 2.24}},
#   {'clouds': {'all': 0},
#    'dt': 1530316800,
#    'dt_txt': '2018-06-30 00:00:00',
#    'main': {'grnd_level': 1029.72,
#     'humidity': 94,
#     'pressure': 1029.72,
#     'sea_level': 1034.33,
#     'temp': 16.2,
#     'temp_kf': 0,
#     'temp_max': 16.2,
#     'temp_min': 16.2},
#    'sys': {'pod': 'n'},
#    'weather': [{'description': 'clear sky',
#      'icon': '01n',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 37.0011, 'speed': 2.12}},
#   {'clouds': {'all': 0},
#    'dt': 1530327600,
#    'dt_txt': '2018-06-30 03:00:00',
#    'main': {'grnd_level': 1028.6,
#     'humidity': 97,
#     'pressure': 1028.6,
#     'sea_level': 1033.36,
#     'temp': 15.67,
#     'temp_kf': 0,
#     'temp_max': 15.67,
#     'temp_min': 15.67},
#    'sys': {'pod': 'n'},
#    'weather': [{'description': 'clear sky',
#      'icon': '01n',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 86.0008, 'speed': 2.45}},
#   {'clouds': {'all': 0},
#    'dt': 1530338400,
#    'dt_txt': '2018-06-30 06:00:00',
#    'main': {'grnd_level': 1028.21,
#     'humidity': 92,
#     'pressure': 1028.21,
#     'sea_level': 1033.03,
#     'temp': 16.45,
#     'temp_kf': 0,
#     'temp_max': 16.45,
#     'temp_min': 16.45},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'clear sky',
#      'icon': '01d',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 141, 'speed': 3.32}},
#   {'clouds': {'all': 0},
#    'dt': 1530349200,
#    'dt_txt': '2018-06-30 09:00:00',
#    'main': {'grnd_level': 1028.31,
#     'humidity': 85,
#     'pressure': 1028.31,
#     'sea_level': 1033.01,
#     'temp': 17.67,
#     'temp_kf': 0,
#     'temp_max': 17.67,
#     'temp_min': 17.67},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'clear sky',
#      'icon': '01d',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 125.501, 'speed': 3.82}},
#   {'clouds': {'all': 0},
#    'dt': 1530360000,
#    'dt_txt': '2018-06-30 12:00:00',
#    'main': {'grnd_level': 1027.73,
#     'humidity': 87,
#     'pressure': 1027.73,
#     'sea_level': 1032.36,
#     'temp': 17.53,
#     'temp_kf': 0,
#     'temp_max': 17.53,
#     'temp_min': 17.53},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'clear sky',
#      'icon': '01d',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 107.005, 'speed': 4.91}},
#   {'clouds': {'all': 8},
#    'dt': 1530370800,
#    'dt_txt': '2018-06-30 15:00:00',
#    'main': {'grnd_level': 1027.05,
#     'humidity': 90,
#     'pressure': 1027.05,
#     'sea_level': 1031.57,
#     'temp': 17.22,
#     'temp_kf': 0,
#     'temp_max': 17.22,
#     'temp_min': 17.22},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'clear sky',
#      'icon': '02d',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 85.0006, 'speed': 4.05}},
#   {'clouds': {'all': 20},
#    'dt': 1530381600,
#    'dt_txt': '2018-06-30 18:00:00',
#    'main': {'grnd_level': 1026.11,
#     'humidity': 89,
#     'pressure': 1026.11,
#     'sea_level': 1030.79,
#     'temp': 17.33,
#     'temp_kf': 0,
#     'temp_max': 17.33,
#     'temp_min': 17.33},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'few clouds',
#      'icon': '02d',
#      'id': 801,
#      'main': 'Clouds'}],
#    'wind': {'deg': 51.0091, 'speed': 2.52}},
#   {'clouds': {'all': 32},
#    'dt': 1530392400,
#    'dt_txt': '2018-06-30 21:00:00',
#    'main': {'grnd_level': 1026.24,
#     'humidity': 93,
#     'pressure': 1026.24,
#     'sea_level': 1030.87,
#     'temp': 16.68,
#     'temp_kf': 0,
#     'temp_max': 16.68,
#     'temp_min': 16.68},
#    'sys': {'pod': 'n'},
#    'weather': [{'description': 'scattered clouds',
#      'icon': '03n',
#      'id': 802,
#      'main': 'Clouds'}],
#    'wind': {'deg': 15.5094, 'speed': 3.14}},
#   {'clouds': {'all': 56},
#    'dt': 1530403200,
#    'dt_txt': '2018-07-01 00:00:00',
#    'main': {'grnd_level': 1026.67,
#     'humidity': 95,
#     'pressure': 1026.67,
#     'sea_level': 1031.27,
#     'temp': 16.29,
#     'temp_kf': 0,
#     'temp_max': 16.29,
#     'temp_min': 16.29},
#    'sys': {'pod': 'n'},
#    'weather': [{'description': 'broken clouds',
#      'icon': '04n',
#      'id': 803,
#      'main': 'Clouds'}],
#    'wind': {'deg': 3.00046, 'speed': 3.32}},
#   {'clouds': {'all': 32},
#    'dt': 1530414000,
#    'dt_txt': '2018-07-01 03:00:00',
#    'main': {'grnd_level': 1027.49,
#     'humidity': 96,
#     'pressure': 1027.49,
#     'sea_level': 1032.24,
#     'temp': 15.89,
#     'temp_kf': 0,
#     'temp_max': 15.89,
#     'temp_min': 15.89},
#    'sys': {'pod': 'n'},
#    'weather': [{'description': 'scattered clouds',
#      'icon': '03n',
#      'id': 802,
#      'main': 'Clouds'}],
#    'wind': {'deg': 10.0013, 'speed': 7.71}},
#   {'clouds': {'all': 0},
#    'dt': 1530424800,
#    'dt_txt': '2018-07-01 06:00:00',
#    'main': {'grnd_level': 1028.77,
#     'humidity': 99,
#     'pressure': 1028.77,
#     'sea_level': 1033.44,
#     'temp': 15.12,
#     'temp_kf': 0,
#     'temp_max': 15.12,
#     'temp_min': 15.12},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'clear sky',
#      'icon': '01d',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 9.50043, 'speed': 8.07}},
#   {'clouds': {'all': 0},
#    'dt': 1530435600,
#    'dt_txt': '2018-07-01 09:00:00',
#    'main': {'grnd_level': 1030.02,
#     'humidity': 93,
#     'pressure': 1030.02,
#     'sea_level': 1034.55,
#     'temp': 16.14,
#     'temp_kf': 0,
#     'temp_max': 16.14,
#     'temp_min': 16.14},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'clear sky',
#      'icon': '01d',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 18.0052, 'speed': 8.23}},
#   {'clouds': {'all': 0},
#    'dt': 1530446400,
#    'dt_txt': '2018-07-01 12:00:00',
#    'main': {'grnd_level': 1030.39,
#     'humidity': 88,
#     'pressure': 1030.39,
#     'sea_level': 1034.97,
#     'temp': 17.01,
#     'temp_kf': 0,
#     'temp_max': 17.01,
#     'temp_min': 17.01},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'clear sky',
#      'icon': '01d',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 26.5102, 'speed': 8.3}},
#   {'clouds': {'all': 0},
#    'dt': 1530457200,
#    'dt_txt': '2018-07-01 15:00:00',
#    'main': {'grnd_level': 1030.11,
#     'humidity': 85,
#     'pressure': 1030.11,
#     'sea_level': 1034.67,
#     'temp': 17.69,
#     'temp_kf': 0,
#     'temp_max': 17.69,
#     'temp_min': 17.69},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'clear sky',
#      'icon': '01d',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 27.5, 'speed': 8.63}},
#   {'clouds': {'all': 0},
#    'dt': 1530468000,
#    'dt_txt': '2018-07-01 18:00:00',
#    'main': {'grnd_level': 1029.84,
#     'humidity': 82,
#     'pressure': 1029.84,
#     'sea_level': 1034.38,
#     'temp': 18.24,
#     'temp_kf': 0,
#     'temp_max': 18.24,
#     'temp_min': 18.24},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'clear sky',
#      'icon': '01d',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 23, 'speed': 8.17}},
#   {'clouds': {'all': 0},
#    'dt': 1530478800,
#    'dt_txt': '2018-07-01 21:00:00',
#    'main': {'grnd_level': 1030.23,
#     'humidity': 83,
#     'pressure': 1030.23,
#     'sea_level': 1034.98,
#     'temp': 17.96,
#     'temp_kf': 0,
#     'temp_max': 17.96,
#     'temp_min': 17.96},
#    'sys': {'pod': 'n'},
#    'weather': [{'description': 'clear sky',
#      'icon': '01n',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 17.0011, 'speed': 8.26}},
#   {'clouds': {'all': 0},
#    'dt': 1530489600,
#    'dt_txt': '2018-07-02 00:00:00',
#    'main': {'grnd_level': 1030.78,
#     'humidity': 89,
#     'pressure': 1030.78,
#     'sea_level': 1035.51,
#     'temp': 17.01,
#     'temp_kf': 0,
#     'temp_max': 17.01,
#     'temp_min': 17.01},
#    'sys': {'pod': 'n'},
#    'weather': [{'description': 'clear sky',
#      'icon': '01n',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 34.5001, 'speed': 7.23}},
#   {'clouds': {'all': 0},
#    'dt': 1530500400,
#    'dt_txt': '2018-07-02 03:00:00',
#    'main': {'grnd_level': 1031.6,
#     'humidity': 92,
#     'pressure': 1031.6,
#     'sea_level': 1036.31,
#     'temp': 16.42,
#     'temp_kf': 0,
#     'temp_max': 16.42,
#     'temp_min': 16.42},
#    'sys': {'pod': 'n'},
#    'weather': [{'description': 'clear sky',
#      'icon': '01n',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 80.002, 'speed': 8.1}},
#   {'clouds': {'all': 0},
#    'dt': 1530511200,
#    'dt_txt': '2018-07-02 06:00:00',
#    'main': {'grnd_level': 1032.59,
#     'humidity': 98,
#     'pressure': 1032.59,
#     'sea_level': 1037.27,
#     'temp': 15.47,
#     'temp_kf': 0,
#     'temp_max': 15.47,
#     'temp_min': 15.47},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'clear sky',
#      'icon': '01d',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 71.5005, 'speed': 8.61}},
#   {'clouds': {'all': 0},
#    'dt': 1530522000,
#    'dt_txt': '2018-07-02 09:00:00',
#    'main': {'grnd_level': 1033.19,
#     'humidity': 97,
#     'pressure': 1033.19,
#     'sea_level': 1037.75,
#     'temp': 15.45,
#     'temp_kf': 0,
#     'temp_max': 15.45,
#     'temp_min': 15.45},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'clear sky',
#      'icon': '01d',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 61.5005, 'speed': 8.81}},
#   {'clouds': {'all': 0},
#    'dt': 1530532800,
#    'dt_txt': '2018-07-02 12:00:00',
#    'main': {'grnd_level': 1033.09,
#     'humidity': 95,
#     'pressure': 1033.09,
#     'sea_level': 1037.67,
#     'temp': 15.86,
#     'temp_kf': 0,
#     'temp_max': 15.86,
#     'temp_min': 15.86},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'clear sky',
#      'icon': '01d',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 52.0006, 'speed': 8.41}},
#   {'clouds': {'all': 0},
#    'dt': 1530543600,
#    'dt_txt': '2018-07-02 15:00:00',
#    'main': {'grnd_level': 1032.16,
#     'humidity': 89,
#     'pressure': 1032.16,
#     'sea_level': 1036.76,
#     'temp': 16.83,
#     'temp_kf': 0,
#     'temp_max': 16.83,
#     'temp_min': 16.83},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'clear sky',
#      'icon': '01d',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 40.5002, 'speed': 8.36}},
#   {'clouds': {'all': 0},
#    'dt': 1530554400,
#    'dt_txt': '2018-07-02 18:00:00',
#    'main': {'grnd_level': 1031.11,
#     'humidity': 86,
#     'pressure': 1031.11,
#     'sea_level': 1035.77,
#     'temp': 17.38,
#     'temp_kf': 0,
#     'temp_max': 17.38,
#     'temp_min': 17.38},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'clear sky',
#      'icon': '01d',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 36.0026, 'speed': 8.52}},
#   {'clouds': {'all': 8},
#    'dt': 1530565200,
#    'dt_txt': '2018-07-02 21:00:00',
#    'main': {'grnd_level': 1031,
#     'humidity': 88,
#     'pressure': 1031,
#     'sea_level': 1035.79,
#     'temp': 17.01,
#     'temp_kf': 0,
#     'temp_max': 17.01,
#     'temp_min': 17.01},
#    'sys': {'pod': 'n'},
#    'weather': [{'description': 'clear sky',
#      'icon': '02n',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 43.001, 'speed': 8.16}},
#   {'clouds': {'all': 0},
#    'dt': 1530576000,
#    'dt_txt': '2018-07-03 00:00:00',
#    'main': {'grnd_level': 1031.08,
#     'humidity': 92,
#     'pressure': 1031.08,
#     'sea_level': 1035.76,
#     'temp': 16.13,
#     'temp_kf': 0,
#     'temp_max': 16.13,
#     'temp_min': 16.13},
#    'sys': {'pod': 'n'},
#    'weather': [{'description': 'clear sky',
#      'icon': '01n',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 70.0026, 'speed': 8.3}},
#   {'clouds': {'all': 24},
#    'dt': 1530586800,
#    'dt_txt': '2018-07-03 03:00:00',
#    'main': {'grnd_level': 1030.73,
#     'humidity': 98,
#     'pressure': 1030.73,
#     'sea_level': 1035.46,
#     'temp': 15.05,
#     'temp_kf': 0,
#     'temp_max': 15.05,
#     'temp_min': 15.05},
#    'sys': {'pod': 'n'},
#    'weather': [{'description': 'few clouds',
#      'icon': '02n',
#      'id': 801,
#      'main': 'Clouds'}],
#    'wind': {'deg': 82.504, 'speed': 8.01}},
#   {'clouds': {'all': 0},
#    'dt': 1530597600,
#    'dt_txt': '2018-07-03 06:00:00',
#    'main': {'grnd_level': 1030.48,
#     'humidity': 100,
#     'pressure': 1030.48,
#     'sea_level': 1035.12,
#     'temp': 14.52,
#     'temp_kf': 0,
#     'temp_max': 14.52,
#     'temp_min': 14.52},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'clear sky',
#      'icon': '01d',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 83.5015, 'speed': 6.52}},
#   {'clouds': {'all': 12},
#    'dt': 1530608400,
#    'dt_txt': '2018-07-03 09:00:00',
#    'main': {'grnd_level': 1030.41,
#     'humidity': 99,
#     'pressure': 1030.41,
#     'sea_level': 1034.99,
#     'temp': 14.85,
#     'temp_kf': 0,
#     'temp_max': 14.85,
#     'temp_min': 14.85},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'few clouds',
#      'icon': '02d',
#      'id': 801,
#      'main': 'Clouds'}],
#    'wind': {'deg': 71.5037, 'speed': 5.71}}],
#  'message': 0.0026}

# %% [markdown]
# Temperature in celsius, humidity in %, pressure in hPa, wind speed in meter/sec, wind direction in degrees, weather description (coded), clouds - in percentage

# %%
#read in the json
df_json = pd.read_json(json_weather)

# write the csv
df.to_csv("forecast_weather.csv")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-b5ea966deaf4> in <module>()
#       1 #read in the json
# ----> 2 df_json = pd.read_json(json_weather)
#
# /Applications/anaconda/lib/python3.6/site-packages/pandas/io/json/json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines)
#     320
#     321     filepath_or_buffer, _, _ = get_filepath_or_buffer(path_or_buf,
# --> 322                                                       encoding=encoding)
#     323     if isinstance(filepath_or_buffer, compat.string_types):
#     324         try:
#
# /Applications/anaconda/lib/python3.6/site-packages/pandas/io/common.py in get_filepath_or_buffer(filepath_or_buffer, encoding, compression)
#     208     if not is_file_like(filepath_or_buffer):
#     209         msg = "Invalid file path or buffer object type: {_type}"
# --> 210         raise ValueError(msg.format(_type=type(filepath_or_buffer)))
#     211
#     212     return filepath_or_buffer, None, compression
#
# ValueError: Invalid file path or buffer object type: <class 'dict'>
